# %%
print(" Welcome to the Simple Linear Regression Model\n")

title = input(" Title of your analysis:\n")

x_label = input("Enter label for independent variable (X): ")
x_values = parse_input(f"Enter values for {x_label} (space-separated): ")
x_sum, x_mean, x_sq_sum = print_summary(x_label, x_values)

y_label = input("\nEnter label for dependent variable (Y): ")
y_values = parse_input(f"Enter values for {y_label} (space-separated): ")
y_sum, y_mean, y_sq_sum = print_summary(y_label, y_values)

print("\n Computing XY products...")
for x, y in zip(x_values, y_values):
    print(x * y)

xy_sum = sum(x * y for x, y in zip(x_values, y_values))
print(f"Summation of XY = {xy_sum}\n")

print(" Calculating regression coefficients...")
b0, b1 = compute_regression(x_values, y_values)

print("\n Regression equation:")
print(f"Y = {b0} + {b1}*X + E (error term)")
print("\n Model computation complete.")
print("Danke für die Analyse! :)")
